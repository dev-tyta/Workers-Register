# %%
import cv2
import face_recognition

# %%
image = face_recognition.load_image_file("../data/player_data/hcantoni.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
face = face_recognition.face_locations(image)[0]
image_copy = image.copy()

# %%
cv2.rectangle(image, (face[3], face[0]), (face[2], face[1]), (0, 0, 255))
# cv2.imshow("Face Recognition", image)
# cv2.imshow("Real Face", image_copy)
# cv2.waitKey(0)
# Out:
# array([[[221, 186, 163],
#         [220, 183, 161],
#         [220, 181, 160],
#         ...,
#         [203, 175, 157],
#         [200, 174, 154],
#         [200, 177, 156]],
#
#        [[221, 189, 169],
#         [219, 185, 165],
#         [217, 181, 162],
#         ...,
#         [209, 182, 162],
#         [207, 183, 162],
#         [207, 186, 164]],
#
#        [[219, 190, 171],
#         [217, 186, 167],
#         [215, 182, 164],
#         ...,
#         [211, 184, 165],
#         [218, 191, 171],
#         [229, 204, 183]],
#
#        ...,
#
#        [[ 90, 154, 153],
#         [ 81, 152, 144],
#         [ 71, 143, 131],
#         ...,
#         [ 68, 121, 102],
#         [ 72, 128, 102],
#         [ 79, 139, 106]],
#
#        [[134, 186, 192],
#         [ 97, 155, 150],
#         [ 65, 123, 110],
#         ...,
#         [ 91, 142, 121],
#         [ 73, 126, 101],
#         [ 75, 131, 102]],
#
#        [[134, 179, 187],
#         [137, 187, 182],
#         [102, 151, 139],
# ...

# %%
train_image = face_recognition.face_encodings(image)[0]

# %%
train_image
# Out:
# array([-0.11864377,  0.13076465,  0.07527485, -0.02222949, -0.04007004,
#        -0.02568388, -0.01544952, -0.07768355,  0.12401856, -0.0584803 ,
#         0.31848231, -0.0502475 , -0.16117658, -0.13011286,  0.0355576 ,
#         0.17794125, -0.20498291, -0.09845067, -0.09911151, -0.20563132,
#        -0.06651979,  0.03048298, -0.03544046,  0.06601189, -0.03792653,
#        -0.24779668, -0.05271183, -0.2149497 ,  0.11156256, -0.17323495,
#         0.03329518,  0.07780383, -0.18958756, -0.04854942, -0.03505804,
#        -0.02958503,  0.08603904,  0.00457543,  0.16534565,  0.00285917,
#        -0.09967113,  0.01685321, -0.00738527,  0.28298584,  0.21143447,
#         0.01403845, -0.04255096,  0.01143144,  0.11142472, -0.11232572,
#         0.05698306,  0.08859947,  0.17791855, -0.00308489, -0.04860912,
#        -0.17176598, -0.06655221,  0.00869575, -0.22167565,  0.04241304,
#         0.11361323, -0.13168612, -0.14229587, -0.0525058 ,  0.22566065,
# ...
